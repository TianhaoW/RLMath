# %%
# run the following if the project root is not in the sys.path.

# import sys
# from pathlib import Path
#
# # Add project root to sys.path
# project_root = Path(__file__).resolve().parent.parent
# sys.path.append(str(project_root))

# %%
from src.envs import Point, NoStrictIsoscelesEnv, NoIsoscelesEnv, NoThreeCollinearEnv

# %% [markdown]
# # Example of playing the No Isosceles triangle game

# %%
env = NoIsoscelesEnv(m=3, n=10)

# %%
env.self_play_add_point(Point(0, 0))

# %%
env.self_play_add_point(Point(2, 0))

# %%
env.self_play_add_point(Point(1, 0))
# Out:
# game over

# %% [markdown]
# # Example of playing the No Strict Isosceles triangle game
#
# Here, a triangle must have non-zero area

# %%
env = NoStrictIsoscelesEnv(m=3, n=10)
env.self_play_add_point(Point(0, 0))
env.self_play_add_point(Point(2, 0))
env.self_play_add_point(Point(1, 0))
env.self_play_add_point(Point(1, 1))
# Out:
# game over

# %% [markdown]
# # Example of playing No 3 point in line

# %%
env = NoThreeCollinearEnv(m=4, n=4)
env.self_play_add_point(Point(0, 0))
env.self_play_add_point(Point(1, 1))
env.self_play_add_point(Point(1, 2))
env.self_play_add_point(Point(1, 3))
# Out:
# game over
