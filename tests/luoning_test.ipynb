# %%
from src.envs import NoThreeCollinear3DEnv, Point3D

env_test = NoThreeCollinear3DEnv(4, 4, 4)

# %%
env_test.add_point(Point3D(0, 0, 0))
env_test.add_point(Point3D(0, 2, 0))
env_test.add_point(Point3D(0, 0, 3))
env_test.add_point(Point3D(1, 2, 1))
# Out:
# (False, 1)

# %%
env_test.plot()
