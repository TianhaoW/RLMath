# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsRegressor

# Load experiment results
csv_path = 'experiment_results.csv'
df = pd.read_csv(csv_path)

# Compute normalized terminal points
df['terminal_num_points_over_n'] = df['terminal_num_points'] / df['n']

# Aggregate statistics by grid size
stats = df.groupby('n')['terminal_num_points_over_n'].agg(['min','mean','max']).reset_index()

# Prepare data for smoothing
X = stats['n'].values.reshape(-1, 1)
min_y, mean_y, max_y = stats['min'].values, stats['mean'].values, stats['max'].values

# Fit KNN (k=3) and predict smoothed values
knn = KNeighborsRegressor(n_neighbors=3)
min_smooth = knn.fit(X, min_y).predict(X)
mean_smooth = knn.fit(X, mean_y).predict(X)
max_smooth = knn.fit(X, max_y).predict(X)

# Plot raw data, original, and smoothed curves
plt.figure(figsize=(8, 6))
plt.scatter(df['n'], df['terminal_num_points_over_n'], color='gray', alpha=0.3, label='Data')
plt.plot(stats['n'], min_smooth, linestyle='--', color='blue', label='Min (smoothed)')
plt.plot(stats['n'], mean_smooth, linestyle='--', color='orange', label='Mean (smoothed)')
plt.plot(stats['n'], max_smooth, linestyle='--', color='green', label='Max (smoothed)')

plt.xlabel('Grid size n')
plt.ylabel('Terminal points / n')
plt.title('KNN (k=3) Fitting of MAX/MEAN/MIN and Normalized Terminal Points vs Grid Size')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np

# Find the largest terminal number of points for each grid size n
largest_points_per_n = df.groupby('n')['terminal_num_points'].max().reset_index()
largest_points_per_n.columns = ['n', 'largest_terminal_points']

# Add normalized values (terminal points / n)
largest_points_per_n['largest_terminal_points_over_n'] = largest_points_per_n['largest_terminal_points'] / largest_points_per_n['n']

# Add comparison with n
largest_points_per_n['comparison'] = np.where(
    largest_points_per_n['largest_terminal_points'] > largest_points_per_n['n'], 
    'greater_than_n', 
    'less_or_equal_to_n'
)

# Filter the original dataframe to get only the rows with maximum terminal points
filtered_df = df.merge(largest_points_per_n, 
                       left_on=['n', 'terminal_num_points'], 
                       right_on=['n', 'largest_terminal_points'],
                       how='inner')

# Drop the redundant column but keep comparison
filtered_df = filtered_df.drop('largest_terminal_points', axis=1)
filtered_df = filtered_df.sort_values(['n', 'terminal_num_points']).reset_index(drop=True)

# Separate points based on comparison with n
greater_than_n = largest_points_per_n[largest_points_per_n['comparison'] == 'greater_than_n']
less_or_equal_to_n = largest_points_per_n[largest_points_per_n['comparison'] == 'less_or_equal_to_n']

print("Largest terminal points for each grid size:")
print(largest_points_per_n)
print(f"\nPoints greater than n: {len(greater_than_n)}")
print(greater_than_n[['n', 'largest_terminal_points', 'largest_terminal_points_over_n']])
print(f"\nPoints less or equal to n: {len(less_or_equal_to_n)}")
print(less_or_equal_to_n[['n', 'largest_terminal_points', 'largest_terminal_points_over_n']])

# Plot the results
plt.figure(figsize=(12, 8))

# Plot all data points (only those within y range 0-2)
df_filtered = df[(df['terminal_num_points_over_n'] >= 0) & (df['terminal_num_points_over_n'] <= 2)]
plt.scatter(df_filtered['n'], df_filtered['terminal_num_points_over_n'], color='lightgray', alpha=0.5, s=20, label='All experiments')

# Highlight largest points based on comparison with n
plt.scatter(greater_than_n['n'], greater_than_n['largest_terminal_points_over_n'], 
            color='red', s=100, marker='o', edgecolors='black', linewidth=2,
            label=f'Largest > n ({len(greater_than_n)} points)', zorder=5)

plt.scatter(less_or_equal_to_n['n'], less_or_equal_to_n['largest_terminal_points_over_n'], 
            color='blue', s=100, marker='s', edgecolors='black', linewidth=2,
            label=f'Largest ≤ n ({len(less_or_equal_to_n)} points)', zorder=5)

# Connect the largest points with a line (sorted by n)
largest_points_sorted = largest_points_per_n.sort_values('n')
plt.plot(largest_points_sorted['n'], largest_points_sorted['largest_terminal_points_over_n'], 
         'green', linewidth=2, linestyle='-', marker='', 
         label='Connected largest points', zorder=4)

# Add reference line y = 1 (when terminal points = n)
plt.axhline(y=1, color='black', linewidth=1, linestyle=':', alpha=0.7, label='y = 1 (terminal points = n)')

plt.xlabel('Grid size n', fontsize=12)
plt.ylabel('Terminal points / n', fontsize=12)
plt.title('Largest Complete Sets (Normalized) vs Grid Size\nwith Connected Line', fontsize=14)
plt.legend(fontsize=10)
plt.grid(True, alpha=0.3)

# Set y-axis range to 0-2
plt.ylim(0, 2)

# Add annotations for special points (only those within y range)
for _, row in greater_than_n.iterrows():
    if 0 <= row['largest_terminal_points_over_n'] <= 2:
        plt.annotate(f'n={int(row["n"])}: {row["largest_terminal_points_over_n"]:.3f}', 
                    (row['n'], row['largest_terminal_points_over_n']), 
                    xytext=(5, 5), textcoords='offset points', fontsize=8, 
                    bbox=dict(boxstyle='round,pad=0.3', facecolor='yellow', alpha=0.7))

plt.tight_layout()
plt.show()

print(f"\nLargest points connected with a simple line using {len(largest_points_per_n)} data points")
print(f"Graph y-axis shows normalized values (terminal points / n) limited to range [0, 2]")
# Out:
# Largest terminal points for each grid size:
#      n  largest_terminal_points  largest_terminal_points_over_n  \
# 0    3                        6                        2.000000
# 1    4                        8                        2.000000
# 2    5                       10                        2.000000
# 3    6                       12                        2.000000
# 4    7                       14                        2.000000
# 5    8                       16                        2.000000
# 6    9                       18                        2.000000
# 7   10                       20                        2.000000
# 8   11                       22                        2.000000
# 9   12                       24                        2.000000
# 10  13                       25                        1.923077
# 11  14                       27                        1.928571
# 12  15                       29                        1.933333
# 13  16                       31                        1.937500
# 14  17                       33                        1.941176
# 15  18                       35                        1.944444
# 16  19                       37                        1.947368
# 17  20                       39                        1.950000
# 18  21                       41                        1.952381
# 19  22                       42                        1.909091
# 20  23                       43                        1.869565
# 21  24                       45                        1.875000
# 22  25                       48                        1.920000
# 23  26                       49                        1.884615
# 24  27                       51                        1.888889
# 25  28                       52                        1.857143
# 26  29                       55                        1.896552
# 27  30                       56                        1.866667
# 28  31                       58                        1.870968
# 29  32                       60                        1.875000
# 30  33                       61                        1.848485
# 31  34                       63                        1.852941
# 32  35                       66                        1.885714
# 33  36                       67                        1.861111
# 34  37                       69                        1.864865
# 35  38                       70                        1.842105
# 36  39                       71                        1.820513
# 37  40                       74                        1.850000
# 38  41                       74                        1.804878
# 39  42                       76                        1.809524
# 40  43                       79                        1.837209
# 41  44                       80                        1.818182
#
#         comparison
# 0   greater_than_n
# 1   greater_than_n
# 2   greater_than_n
# 3   greater_than_n
# 4   greater_than_n
# 5   greater_than_n
# 6   greater_than_n
# 7   greater_than_n
# 8   greater_than_n
# 9   greater_than_n
# 10  greater_than_n
# 11  greater_than_n
# 12  greater_than_n
# 13  greater_than_n
# 14  greater_than_n
# 15  greater_than_n
# 16  greater_than_n
# 17  greater_than_n
# 18  greater_than_n
# 19  greater_than_n
# 20  greater_than_n
# 21  greater_than_n
# 22  greater_than_n
# 23  greater_than_n
# 24  greater_than_n
# 25  greater_than_n
# 26  greater_than_n
# 27  greater_than_n
# 28  greater_than_n
# 29  greater_than_n
# 30  greater_than_n
# 31  greater_than_n
# 32  greater_than_n
# 33  greater_than_n
# 34  greater_than_n
# 35  greater_than_n
# 36  greater_than_n
# 37  greater_than_n
# 38  greater_than_n
# 39  greater_than_n
# 40  greater_than_n
# 41  greater_than_n
#
# Points greater than n: 42
#      n  largest_terminal_points  largest_terminal_points_over_n
# 0    3                        6                        2.000000
# 1    4                        8                        2.000000
# 2    5                       10                        2.000000
# 3    6                       12                        2.000000
# 4    7                       14                        2.000000
# 5    8                       16                        2.000000
# 6    9                       18                        2.000000
# 7   10                       20                        2.000000
# 8   11                       22                        2.000000
# 9   12                       24                        2.000000
# 10  13                       25                        1.923077
# 11  14                       27                        1.928571
# 12  15                       29                        1.933333
# 13  16                       31                        1.937500
# 14  17                       33                        1.941176
# 15  18                       35                        1.944444
# 16  19                       37                        1.947368
# 17  20                       39                        1.950000
# 18  21                       41                        1.952381
# 19  22                       42                        1.909091
# 20  23                       43                        1.869565
# 21  24                       45                        1.875000
# 22  25                       48                        1.920000
# 23  26                       49                        1.884615
# 24  27                       51                        1.888889
# 25  28                       52                        1.857143
# 26  29                       55                        1.896552
# 27  30                       56                        1.866667
# 28  31                       58                        1.870968
# 29  32                       60                        1.875000
# 30  33                       61                        1.848485
# 31  34                       63                        1.852941
# 32  35                       66                        1.885714
# 33  36                       67                        1.861111
# 34  37                       69                        1.864865
# 35  38                       70                        1.842105
# 36  39                       71                        1.820513
# 37  40                       74                        1.850000
# 38  41                       74                        1.804878
# 39  42                       76                        1.809524
# 40  43                       79                        1.837209
# 41  44                       80                        1.818182
#
# Points less or equal to n: 0
# Empty DataFrame
# Columns: [n, largest_terminal_points, largest_terminal_points_over_n]
# Index: []
# Largest points connected with a simple line using 42 data points
# Graph y-axis shows normalized values (terminal points / n) limited to range [0, 2]

# %%
# Output unique smallest terminal points data - one per grid size n
print("Unique smallest complete sets - One experiment per grid size:")
print("=" * 80)

# Get one representative experiment per grid size that achieved the minimum
# We'll take the first one if there are multiple experiments with the same minimum
unique_smallest = filtered_df.groupby('n').first().reset_index()

# Create full figure path by concatenating figure_dir and session_name
if 'session_name' in unique_smallest.columns and 'figure_dir' in unique_smallest.columns:
    unique_smallest['full_figure_path'] = unique_smallest['figure_dir'] + '/' + unique_smallest['session_name']
    display_columns = ['n', 'terminal_num_points', 'full_figure_path']
elif 'figure_dir' in unique_smallest.columns:
    display_columns = ['n', 'terminal_num_points', 'figure_dir']
else:
    # Check if there are other directory-related columns
    dir_columns = [col for col in unique_smallest.columns if 'dir' in col.lower()]
    if dir_columns:
        display_columns = ['n', 'terminal_num_points'] + dir_columns
    else:
        # Show key columns if no directory columns found
        key_columns = ['n', 'terminal_num_points']
        # Add some other useful columns if they exist
        for col in ['time_used', 'random_seed', 'terminal_num_points_over_n', 'session_name']:
            if col in unique_smallest.columns:
                key_columns.append(col)
        display_columns = key_columns

# Display the unique results
unique_display = unique_smallest[display_columns].copy()

# Sort by n for better readability
unique_display = unique_display.sort_values('n').reset_index(drop=True)

print(f"Total grid sizes: {len(unique_display)}")
print(f"Columns shown: {', '.join(display_columns)}")
print("\nData (one experiment per grid size):")
print(unique_display.to_string(index=False))

# Summary statistics
print(f"\nSummary:")
print(f"Grid sizes covered: {sorted(unique_display['n'].unique())}")
print(f"Range of smallest complete sets: {unique_display['terminal_num_points'].min()} to {unique_display['terminal_num_points'].max()}")

# Show the n vs terminal_num_points mapping clearly
print(f"\nGrid size → Smallest complete set mapping:")
for _, row in unique_display.iterrows():
    ratio = row['terminal_num_points'] / row['n']
    print(f"n={int(row['n']):2d} → {int(row['terminal_num_points']):2d} points (ratio: {ratio:.3f})")

# Show available columns for reference
print(f"\nAvailable columns in dataset: {list(unique_smallest.columns)}")
if 'full_figure_path' in unique_smallest.columns:
    print("\nFull figure paths for HPC3 access:")
    for _, row in unique_display.iterrows():
        print(f"n={int(row['n']):2d}: {row['full_figure_path']}")
elif 'session_name' in unique_smallest.columns:
    print("\nFigure directories with session names:")
    for _, row in unique_display.iterrows():
        session = row.get('session_name', 'N/A')
        fig_dir = row.get('figure_dir', 'N/A')
        print(f"n={int(row['n']):2d}: {fig_dir}/{session}")
# Out:
# Unique smallest complete sets - One experiment per grid size:
# ================================================================================
# Total grid sizes: 42
# Columns shown: n, terminal_num_points, full_figure_path
#
# Data (one experiment per grid size):
#  n  terminal_num_points                                                                                                                 full_figure_path
#  3                    6   /Users/luoninz1/063_Research/no-three-in-line/Code/RLMath/tests/test_mcts_largest_complete_v2 copy/figure/20250813_105507_3by3
#  4                    8                                        /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115320_4by4
#  5                   10                                        /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115320_5by5
#  6                   11                                        /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_120405_6by6
#  7                   14                                        /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115319_7by7
#  8                   15                                        /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115727_8by8
#  9                   17                                        /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115436_9by9
# 10                   19 /Users/luoninz1/063_Research/no-three-in-line/Code/RLMath/tests/test_mcts_largest_complete_v2 copy/figure/20250813_105535_10by10
# 11                   20                                      /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115952_11by11
# 12                   22                                      /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115329_12by12
# 13                   24                                      /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115622_13by13
# 14                   26                                      /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115659_14by14
# 15                   28                                      /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115759_15by15
# 16                   30                                      /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115321_16by16
# 17                   31                                      /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_120017_17by17
# 18                   33                                      /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_124705_18by18
# 19                   35                                      /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_120406_19by19
# 20                   37                                      /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_120857_20by20
# 21                   39                                      /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_121602_21by21
# 22                   40                                      /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_133835_22by22
# 23                   42                                      /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115827_23by23
# 24                   44                                      /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_144032_24by24
# 25                   46                                      /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115646_25by25
# 26                   48                                      /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_142207_26by26
# 27                   49                                      /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_161724_27by27
# 28                   51                                      /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115631_28by28
# 29                   53                                      /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115631_29by29
# 30                   54                                      /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_211434_30by30
# 31                   57                                      /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_134914_31by31
# 32                   58                                      /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_195849_32by32
# 33                   60                                      /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115634_33by33
# 34                   61                                      /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115713_34by34
# 35                   64                                      /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115631_35by35
# 36                   66                                      /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_155709_36by36
# 37                   68                                      /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115631_37by37
# 38                   69                                      /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_172308_38by38
# 39                   71                                      /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115631_39by39
# 40                   73                                      /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_120008_40by40
# 41                   74                                      /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_120111_41by41
# 42                   76                                      /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_120008_42by42
# 43                   79                                      /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_120028_43by43
# 44                   80                                      /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_120113_44by44
#
# Summary:
# Grid sizes covered: [np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7), np.int64(8), np.int64(9), np.int64(10), np.int64(11), np.int64(12), np.int64(13), np.int64(14), np.int64(15), np.int64(16), np.int64(17), np.int64(18), np.int64(19), np.int64(20), np.int64(21), np.int64(22), np.int64(23), np.int64(24), np.int64(25), np.int64(26), np.int64(27), np.int64(28), np.int64(29), np.int64(30), np.int64(31), np.int64(32), np.int64(33), np.int64(34), np.int64(35), np.int64(36), np.int64(37), np.int64(38), np.int64(39), np.int64(40), np.int64(41), np.int64(42), np.int64(43), np.int64(44)]
# Range of smallest complete sets: 6 to 80
#
# Grid size → Smallest complete set mapping:
# n= 3 →  6 points (ratio: 2.000)
# n= 4 →  8 points (ratio: 2.000)
# n= 5 → 10 points (ratio: 2.000)
# n= 6 → 11 points (ratio: 1.833)
# n= 7 → 14 points (ratio: 2.000)
# n= 8 → 15 points (ratio: 1.875)
# n= 9 → 17 points (ratio: 1.889)
# n=10 → 19 points (ratio: 1.900)
# n=11 → 20 points (ratio: 1.818)
# n=12 → 22 points (ratio: 1.833)
# n=13 → 24 points (ratio: 1.846)
# n=14 → 26 points (ratio: 1.857)
# n=15 → 28 points (ratio: 1.867)
# n=16 → 30 points (ratio: 1.875)
# n=17 → 31 points (ratio: 1.824)
# n=18 → 33 points (ratio: 1.833)
# n=19 → 35 points (ratio: 1.842)
# n=20 → 37 points (ratio: 1.850)
# n=21 → 39 points (ratio: 1.857)
# n=22 → 40 points (ratio: 1.818)
# n=23 → 42 points (ratio: 1.826)
# n=24 → 44 points (ratio: 1.833)
# n=25 → 46 points (ratio: 1.840)
# n=26 → 48 points (ratio: 1.846)
# n=27 → 49 points (ratio: 1.815)
# n=28 → 51 points (ratio: 1.821)
# n=29 → 53 points (ratio: 1.828)
# n=30 → 54 points (ratio: 1.800)
# n=31 → 57 points (ratio: 1.839)
# n=32 → 58 points (ratio: 1.812)
# n=33 → 60 points (ratio: 1.818)
# n=34 → 61 points (ratio: 1.794)
# n=35 → 64 points (ratio: 1.829)
# n=36 → 66 points (ratio: 1.833)
# n=37 → 68 points (ratio: 1.838)
# n=38 → 69 points (ratio: 1.816)
# n=39 → 71 points (ratio: 1.821)
# n=40 → 73 points (ratio: 1.825)
# n=41 → 74 points (ratio: 1.805)
# n=42 → 76 points (ratio: 1.810)
# n=43 → 79 points (ratio: 1.837)
# n=44 → 80 points (ratio: 1.818)
#
# Available columns in dataset: ['n', 'environment', 'algorithm', 'max_level_to_use_symmetry', 'C', 'num_searches', 'num_workers', 'virtual_loss', 'process_bar', 'display_state', 'logging_mode', 'TopN', 'simulate_with_priority', 'table_dir', 'figure_dir', 'random_seed', 'tree_visualization', 'pause_at_each_step', 'terminal_num_points', 'session_name', 'start_time', 'end_time', 'time_used', 'terminal_num_points_over_n', 'smallest_terminal_points_over_n', 'comparison', 'full_figure_path']
#
# Full figure paths for HPC3 access:
# n= 3: /Users/luoninz1/063_Research/no-three-in-line/Code/RLMath/tests/test_mcts_largest_complete_v2 copy/figure/20250813_105507_3by3
# n= 4: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115320_4by4
# n= 5: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115320_5by5
# n= 6: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_120405_6by6
# n= 7: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115319_7by7
# n= 8: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115727_8by8
# n= 9: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115436_9by9
# n=10: /Users/luoninz1/063_Research/no-three-in-line/Code/RLMath/tests/test_mcts_largest_complete_v2 copy/figure/20250813_105535_10by10
# n=11: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115952_11by11
# n=12: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115329_12by12
# n=13: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115622_13by13
# n=14: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115659_14by14
# n=15: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115759_15by15
# n=16: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115321_16by16
# n=17: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_120017_17by17
# n=18: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_124705_18by18
# n=19: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_120406_19by19
# n=20: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_120857_20by20
# n=21: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_121602_21by21
# n=22: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_133835_22by22
# n=23: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115827_23by23
# n=24: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_144032_24by24
# n=25: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115646_25by25
# n=26: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_142207_26by26
# n=27: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_161724_27by27
# n=28: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115631_28by28
# n=29: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115631_29by29
# n=30: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_211434_30by30
# n=31: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_134914_31by31
# n=32: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_195849_32by32
# n=33: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115634_33by33
# n=34: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115713_34by34
# n=35: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115631_35by35
# n=36: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_155709_36by36
# n=37: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115631_37by37
# n=38: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_172308_38by38
# n=39: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_115631_39by39
# n=40: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_120008_40by40
# n=41: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_120111_41by41
# n=42: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_120008_42by42
# n=43: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_120028_43by43
# n=44: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_largest_complete_v2/figure/20250813_120113_44by44
