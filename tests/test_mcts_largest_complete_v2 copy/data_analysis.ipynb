# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsRegressor

# Load experiment results
csv_path = 'experiment_results.csv'
df = pd.read_csv(csv_path)

# Compute normalized terminal points
df['terminal_num_points_over_n'] = df['terminal_num_points'] / df['n']

# Aggregate statistics by grid size
stats = df.groupby('n')['terminal_num_points_over_n'].agg(['min','mean','max']).reset_index()

# Prepare data for smoothing
X = stats['n'].values.reshape(-1, 1)
min_y, mean_y, max_y = stats['min'].values, stats['mean'].values, stats['max'].values

# Fit KNN (k=3) and predict smoothed values
knn = KNeighborsRegressor(n_neighbors=3)
min_smooth = knn.fit(X, min_y).predict(X)
mean_smooth = knn.fit(X, mean_y).predict(X)
max_smooth = knn.fit(X, max_y).predict(X)

# Plot raw data, original, and smoothed curves
plt.figure(figsize=(8, 6))
plt.scatter(df['n'], df['terminal_num_points_over_n'], color='gray', alpha=0.3, label='Data')
plt.plot(stats['n'], min_smooth, linestyle='--', color='blue', label='Min (smoothed)')
plt.plot(stats['n'], mean_smooth, linestyle='--', color='orange', label='Mean (smoothed)')
plt.plot(stats['n'], max_smooth, linestyle='--', color='green', label='Max (smoothed)')

plt.xlabel('Grid size n')
plt.ylabel('Terminal points / n')
plt.title('KNN (k=3) Fitting of MAX/MEAN/MIN and Normalized Terminal Points vs Grid Size')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np

# Find the smallest terminal number of points for each grid size n
smallest_points_per_n = df.groupby('n')['terminal_num_points'].min().reset_index()
smallest_points_per_n.columns = ['n', 'smallest_terminal_points']

# Add normalized values (terminal points / n)
smallest_points_per_n['smallest_terminal_points_over_n'] = smallest_points_per_n['smallest_terminal_points'] / smallest_points_per_n['n']

# Add comparison with n
smallest_points_per_n['comparison'] = np.where(
    smallest_points_per_n['smallest_terminal_points'] < smallest_points_per_n['n'], 
    'smaller_than_n', 
    'equal_to_n'
)

# Filter the original dataframe to get only the rows with minimum terminal points
filtered_df = df.merge(smallest_points_per_n, 
                       left_on=['n', 'terminal_num_points'], 
                       right_on=['n', 'smallest_terminal_points'],
                       how='inner')

# Drop the redundant column but keep comparison
filtered_df = filtered_df.drop('smallest_terminal_points', axis=1)
filtered_df = filtered_df.sort_values(['n', 'terminal_num_points']).reset_index(drop=True)

# Separate points based on comparison with n
smaller_than_n = smallest_points_per_n[smallest_points_per_n['comparison'] == 'smaller_than_n']
equal_to_n = smallest_points_per_n[smallest_points_per_n['comparison'] == 'equal_to_n']

print("Smallest terminal points for each grid size:")
print(smallest_points_per_n)
print(f"\nPoints smaller than n: {len(smaller_than_n)}")
print(smaller_than_n[['n', 'smallest_terminal_points', 'smallest_terminal_points_over_n']])
print(f"\nPoints equal to n: {len(equal_to_n)}")
print(equal_to_n[['n', 'smallest_terminal_points', 'smallest_terminal_points_over_n']])

# Plot the results
plt.figure(figsize=(12, 8))

# Plot all data points (only those within y range 0-2)
df_filtered = df[(df['terminal_num_points_over_n'] >= 0) & (df['terminal_num_points_over_n'] <= 2)]
plt.scatter(df_filtered['n'], df_filtered['terminal_num_points_over_n'], color='lightgray', alpha=0.5, s=20, label='All experiments')

# Highlight smallest points based on comparison with n
plt.scatter(smaller_than_n['n'], smaller_than_n['smallest_terminal_points_over_n'], 
            color='red', s=100, marker='o', edgecolors='black', linewidth=2,
            label=f'Smallest < n ({len(smaller_than_n)} points)', zorder=5)

plt.scatter(equal_to_n['n'], equal_to_n['smallest_terminal_points_over_n'], 
            color='blue', s=100, marker='s', edgecolors='black', linewidth=2,
            label=f'Smallest = n ({len(equal_to_n)} points)', zorder=5)

# Connect the smallest points with a line (sorted by n)
smallest_points_sorted = smallest_points_per_n.sort_values('n')
plt.plot(smallest_points_sorted['n'], smallest_points_sorted['smallest_terminal_points_over_n'], 
         'green', linewidth=2, linestyle='-', marker='', 
         label='Connected smallest points', zorder=4)

# Add reference line y = 1 (when terminal points = n)
plt.axhline(y=1, color='black', linewidth=1, linestyle=':', alpha=0.7, label='y = 1 (terminal points = n)')

plt.xlabel('Grid size n', fontsize=12)
plt.ylabel('Terminal points / n', fontsize=12)
plt.title('Smallest Complete Sets (Normalized) vs Grid Size\nwith Connected Line', fontsize=14)
plt.legend(fontsize=10)
plt.grid(True, alpha=0.3)

# Set y-axis range to 0-2
plt.ylim(0, 2)

# Add annotations for special points (only those within y range)
for _, row in smaller_than_n.iterrows():
    if 0 <= row['smallest_terminal_points_over_n'] <= 2:
        plt.annotate(f'n={int(row["n"])}: {row["smallest_terminal_points_over_n"]:.3f}', 
                    (row['n'], row['smallest_terminal_points_over_n']), 
                    xytext=(5, 5), textcoords='offset points', fontsize=8, 
                    bbox=dict(boxstyle='round,pad=0.3', facecolor='yellow', alpha=0.7))

plt.tight_layout()
plt.show()

print(f"\nSmallest points connected with a simple line using {len(smallest_points_per_n)} data points")
print(f"Graph y-axis shows normalized values (terminal points / n) limited to range [0, 2]")
# Out:
# Smallest terminal points for each grid size:
#      n  smallest_terminal_points  smallest_terminal_points_over_n  \
# 0    3                         4                         1.333333
# 1    4                         4                         1.000000
# 2    5                         6                         1.200000
# 3    6                         6                         1.000000
# 4    7                         8                         1.142857
# 5    8                         8                         1.000000
# 6    9                         9                         1.000000
# 7   10                        10                         1.000000
# 8   11                        10                         0.909091
# 9   12                        12                         1.000000
# 10  13                        12                         0.923077
# 11  14                        14                         1.000000
# 12  15                        15                         1.000000
# 13  16                        16                         1.000000
# 14  17                        16                         0.941176
# 15  18                        17                         0.944444
# 16  19                        19                         1.000000
# 17  20                        20                         1.000000
# 18  21                        20                         0.952381
# 19  22                        22                         1.000000
# 20  23                        22                         0.956522
# 21  25                        25                         1.000000
# 22  26                        26                         1.000000
# 23  27                        27                         1.000000
# 24  28                        29                         1.035714
# 25  29                        30                         1.034483
# 26  30                        31                         1.033333
# 27  31                        32                         1.032258
# 28  32                        33                         1.031250
# 29  33                        34                         1.030303
# 30  34                        34                         1.000000
# 31  35                        36                         1.028571
# 32  36                        37                         1.027778
# 33  37                        39                         1.054054
# 34  38                        40                         1.052632
# 35  39                        41                         1.051282
# 36  40                        42                         1.050000
# 37  41                        43                         1.048780
# 38  42                        44                         1.047619
# 39  43                        45                         1.046512
# 40  44                        46                         1.045455
# 41  45                        47                         1.044444
# 42  46                        48                         1.043478
# 43  47                        50                         1.063830
# 44  48                        51                         1.062500
# 45  50                        53                         1.060000
# 46  51                        54                         1.058824
# 47  52                        55                         1.057692
# 48  53                        56                         1.056604
# 49  54                        58                         1.074074
# 50  55                        58                         1.054545
# 51  56                        60                         1.071429
# 52  57                        60                         1.052632
# 53  58                        62                         1.068966
# 54  59                        63                         1.067797
#
#         comparison
# 0       equal_to_n
# 1       equal_to_n
# 2       equal_to_n
# 3       equal_to_n
# 4       equal_to_n
# 5       equal_to_n
# 6       equal_to_n
# 7       equal_to_n
# 8   smaller_than_n
# 9       equal_to_n
# 10  smaller_than_n
# 11      equal_to_n
# 12      equal_to_n
# 13      equal_to_n
# 14  smaller_than_n
# 15  smaller_than_n
# 16      equal_to_n
# 17      equal_to_n
# 18  smaller_than_n
# 19      equal_to_n
# 20  smaller_than_n
# 21      equal_to_n
# 22      equal_to_n
# 23      equal_to_n
# 24      equal_to_n
# 25      equal_to_n
# 26      equal_to_n
# 27      equal_to_n
# 28      equal_to_n
# 29      equal_to_n
# 30      equal_to_n
# 31      equal_to_n
# 32      equal_to_n
# 33      equal_to_n
# 34      equal_to_n
# 35      equal_to_n
# 36      equal_to_n
# 37      equal_to_n
# 38      equal_to_n
# 39      equal_to_n
# 40      equal_to_n
# 41      equal_to_n
# 42      equal_to_n
# 43      equal_to_n
# 44      equal_to_n
# 45      equal_to_n
# 46      equal_to_n
# 47      equal_to_n
# 48      equal_to_n
# 49      equal_to_n
# 50      equal_to_n
# 51      equal_to_n
# 52      equal_to_n
# 53      equal_to_n
# 54      equal_to_n
#
# Points smaller than n: 6
#      n  smallest_terminal_points  smallest_terminal_points_over_n
# 8   11                        10                         0.909091
# 10  13                        12                         0.923077
# 14  17                        16                         0.941176
# 15  18                        17                         0.944444
# 18  21                        20                         0.952381
# 20  23                        22                         0.956522
#
# Points equal to n: 49
#      n  smallest_terminal_points  smallest_terminal_points_over_n
# 0    3                         4                         1.333333
# 1    4                         4                         1.000000
# 2    5                         6                         1.200000
# 3    6                         6                         1.000000
# 4    7                         8                         1.142857
# 5    8                         8                         1.000000
# 6    9                         9                         1.000000
# 7   10                        10                         1.000000
# 9   12                        12                         1.000000
# 11  14                        14                         1.000000
# 12  15                        15                         1.000000
# 13  16                        16                         1.000000
# 16  19                        19                         1.000000
# 17  20                        20                         1.000000
# 19  22                        22                         1.000000
# 21  25                        25                         1.000000
# 22  26                        26                         1.000000
# 23  27                        27                         1.000000
# 24  28                        29                         1.035714
# 25  29                        30                         1.034483
# 26  30                        31                         1.033333
# 27  31                        32                         1.032258
# 28  32                        33                         1.031250
# 29  33                        34                         1.030303
# 30  34                        34                         1.000000
# 31  35                        36                         1.028571
# 32  36                        37                         1.027778
# 33  37                        39                         1.054054
# 34  38                        40                         1.052632
# 35  39                        41                         1.051282
# 36  40                        42                         1.050000
# 37  41                        43                         1.048780
# 38  42                        44                         1.047619
# 39  43                        45                         1.046512
# 40  44                        46                         1.045455
# 41  45                        47                         1.044444
# 42  46                        48                         1.043478
# 43  47                        50                         1.063830
# 44  48                        51                         1.062500
# 45  50                        53                         1.060000
# 46  51                        54                         1.058824
# 47  52                        55                         1.057692
# 48  53                        56                         1.056604
# 49  54                        58                         1.074074
# 50  55                        58                         1.054545
# 51  56                        60                         1.071429
# 52  57                        60                         1.052632
# 53  58                        62                         1.068966
# 54  59                        63                         1.067797
# Smallest points connected with a simple line using 55 data points
# Graph y-axis shows normalized values (terminal points / n) limited to range [0, 2]

# %%
# Output unique smallest terminal points data - one per grid size n
print("Unique smallest complete sets - One experiment per grid size:")
print("=" * 80)

# Get one representative experiment per grid size that achieved the minimum
# We'll take the first one if there are multiple experiments with the same minimum
unique_smallest = filtered_df.groupby('n').first().reset_index()

# Create full figure path by concatenating figure_dir and session_name
if 'session_name' in unique_smallest.columns and 'figure_dir' in unique_smallest.columns:
    unique_smallest['full_figure_path'] = unique_smallest['figure_dir'] + '/' + unique_smallest['session_name']
    display_columns = ['n', 'terminal_num_points', 'full_figure_path']
elif 'figure_dir' in unique_smallest.columns:
    display_columns = ['n', 'terminal_num_points', 'figure_dir']
else:
    # Check if there are other directory-related columns
    dir_columns = [col for col in unique_smallest.columns if 'dir' in col.lower()]
    if dir_columns:
        display_columns = ['n', 'terminal_num_points'] + dir_columns
    else:
        # Show key columns if no directory columns found
        key_columns = ['n', 'terminal_num_points']
        # Add some other useful columns if they exist
        for col in ['time_used', 'random_seed', 'terminal_num_points_over_n', 'session_name']:
            if col in unique_smallest.columns:
                key_columns.append(col)
        display_columns = key_columns

# Display the unique results
unique_display = unique_smallest[display_columns].copy()

# Sort by n for better readability
unique_display = unique_display.sort_values('n').reset_index(drop=True)

print(f"Total grid sizes: {len(unique_display)}")
print(f"Columns shown: {', '.join(display_columns)}")
print("\nData (one experiment per grid size):")
print(unique_display.to_string(index=False))

# Summary statistics
print(f"\nSummary:")
print(f"Grid sizes covered: {sorted(unique_display['n'].unique())}")
print(f"Range of smallest complete sets: {unique_display['terminal_num_points'].min()} to {unique_display['terminal_num_points'].max()}")

# Show the n vs terminal_num_points mapping clearly
print(f"\nGrid size → Smallest complete set mapping:")
for _, row in unique_display.iterrows():
    ratio = row['terminal_num_points'] / row['n']
    print(f"n={int(row['n']):2d} → {int(row['terminal_num_points']):2d} points (ratio: {ratio:.3f})")

# Show available columns for reference
print(f"\nAvailable columns in dataset: {list(unique_smallest.columns)}")
if 'full_figure_path' in unique_smallest.columns:
    print("\nFull figure paths for HPC3 access:")
    for _, row in unique_display.iterrows():
        print(f"n={int(row['n']):2d}: {row['full_figure_path']}")
elif 'session_name' in unique_smallest.columns:
    print("\nFigure directories with session names:")
    for _, row in unique_display.iterrows():
        session = row.get('session_name', 'N/A')
        fig_dir = row.get('figure_dir', 'N/A')
        print(f"n={int(row['n']):2d}: {fig_dir}/{session}")
# Out:
# Unique smallest complete sets - One experiment per grid size:
# ================================================================================
# Total grid sizes: 55
# Columns shown: n, terminal_num_points, full_figure_path
#
# Data (one experiment per grid size):
#  n  terminal_num_points                                                                             full_figure_path
#  3                    4   /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_180844_3by3
#  4                    4   /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_180844_4by4
#  5                    6   /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_180844_5by5
#  6                    6   /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_181045_6by6
#  7                    8   /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_173447_7by7
#  8                    8   /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_181004_8by8
#  9                    9   /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_181002_9by9
# 10                   10 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_181018_10by10
# 11                   10 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_181028_11by11
# 12                   12 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_180856_12by12
# 13                   12 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_183543_13by13
# 14                   14 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_180855_14by14
# 15                   15 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_185102_15by15
# 16                   16 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_183834_16by16
# 17                   16 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_180852_17by17
# 18                   17 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_192002_18by18
# 19                   19 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_185004_19by19
# 20                   20 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_182846_20by20
# 21                   20 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_203259_21by21
# 22                   22 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_182358_22by22
# 23                   22 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_200306_23by23
# 25                   25 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_205224_25by25
# 26                   26 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_222405_26by26
# 27                   27 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_192450_27by27
# 28                   29 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_184041_28by28
# 29                   30 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_180852_29by29
# 30                   31 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_194341_30by30
# 31                   32 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_234655_31by31
# 32                   33 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_222132_32by32
# 33                   34 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250813_085901_33by33
# 34                   34 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_194040_34by34
# 35                   36 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250813_033423_35by35
# 36                   37 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_234724_36by36
# 37                   39 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_180853_37by37
# 38                   40 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250813_060845_38by38
# 39                   41 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250813_045414_39by39
# 40                   42 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_212642_40by40
# 41                   43 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_180858_41by41
# 42                   44 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250813_024352_42by42
# 43                   45 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_230956_43by43
# 44                   46 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250813_043353_44by44
# 45                   47 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_180857_45by45
# 46                   48 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_180857_46by46
# 47                   50 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250813_021336_47by47
# 48                   51 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_180855_48by48
# 50                   53 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250813_004840_50by50
# 51                   54 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_192119_51by51
# 52                   55 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_180853_52by52
# 53                   56 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_181426_53by53
# 54                   58 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_192119_54by54
# 55                   58 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_192118_55by55
# 56                   60 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_182354_56by56
# 57                   60 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_182715_57by57
# 58                   62 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_183019_58by58
# 59                   63 /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_183459_59by59
#
# Summary:
# Grid sizes covered: [np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7), np.int64(8), np.int64(9), np.int64(10), np.int64(11), np.int64(12), np.int64(13), np.int64(14), np.int64(15), np.int64(16), np.int64(17), np.int64(18), np.int64(19), np.int64(20), np.int64(21), np.int64(22), np.int64(23), np.int64(25), np.int64(26), np.int64(27), np.int64(28), np.int64(29), np.int64(30), np.int64(31), np.int64(32), np.int64(33), np.int64(34), np.int64(35), np.int64(36), np.int64(37), np.int64(38), np.int64(39), np.int64(40), np.int64(41), np.int64(42), np.int64(43), np.int64(44), np.int64(45), np.int64(46), np.int64(47), np.int64(48), np.int64(50), np.int64(51), np.int64(52), np.int64(53), np.int64(54), np.int64(55), np.int64(56), np.int64(57), np.int64(58), np.int64(59)]
# Range of smallest complete sets: 4 to 63
#
# Grid size → Smallest complete set mapping:
# n= 3 →  4 points (ratio: 1.333)
# n= 4 →  4 points (ratio: 1.000)
# n= 5 →  6 points (ratio: 1.200)
# n= 6 →  6 points (ratio: 1.000)
# n= 7 →  8 points (ratio: 1.143)
# n= 8 →  8 points (ratio: 1.000)
# n= 9 →  9 points (ratio: 1.000)
# n=10 → 10 points (ratio: 1.000)
# n=11 → 10 points (ratio: 0.909)
# n=12 → 12 points (ratio: 1.000)
# n=13 → 12 points (ratio: 0.923)
# n=14 → 14 points (ratio: 1.000)
# n=15 → 15 points (ratio: 1.000)
# n=16 → 16 points (ratio: 1.000)
# n=17 → 16 points (ratio: 0.941)
# n=18 → 17 points (ratio: 0.944)
# n=19 → 19 points (ratio: 1.000)
# n=20 → 20 points (ratio: 1.000)
# n=21 → 20 points (ratio: 0.952)
# n=22 → 22 points (ratio: 1.000)
# n=23 → 22 points (ratio: 0.957)
# n=25 → 25 points (ratio: 1.000)
# n=26 → 26 points (ratio: 1.000)
# n=27 → 27 points (ratio: 1.000)
# n=28 → 29 points (ratio: 1.036)
# n=29 → 30 points (ratio: 1.034)
# n=30 → 31 points (ratio: 1.033)
# n=31 → 32 points (ratio: 1.032)
# n=32 → 33 points (ratio: 1.031)
# n=33 → 34 points (ratio: 1.030)
# n=34 → 34 points (ratio: 1.000)
# n=35 → 36 points (ratio: 1.029)
# n=36 → 37 points (ratio: 1.028)
# n=37 → 39 points (ratio: 1.054)
# n=38 → 40 points (ratio: 1.053)
# n=39 → 41 points (ratio: 1.051)
# n=40 → 42 points (ratio: 1.050)
# n=41 → 43 points (ratio: 1.049)
# n=42 → 44 points (ratio: 1.048)
# n=43 → 45 points (ratio: 1.047)
# n=44 → 46 points (ratio: 1.045)
# n=45 → 47 points (ratio: 1.044)
# n=46 → 48 points (ratio: 1.043)
# n=47 → 50 points (ratio: 1.064)
# n=48 → 51 points (ratio: 1.062)
# n=50 → 53 points (ratio: 1.060)
# n=51 → 54 points (ratio: 1.059)
# n=52 → 55 points (ratio: 1.058)
# n=53 → 56 points (ratio: 1.057)
# n=54 → 58 points (ratio: 1.074)
# n=55 → 58 points (ratio: 1.055)
# n=56 → 60 points (ratio: 1.071)
# n=57 → 60 points (ratio: 1.053)
# n=58 → 62 points (ratio: 1.069)
# n=59 → 63 points (ratio: 1.068)
#
# Available columns in dataset: ['n', 'environment', 'algorithm', 'max_level_to_use_symmetry', 'C', 'num_searches', 'num_workers', 'virtual_loss', 'process_bar', 'display_state', 'logging_mode', 'TopN', 'simulate_with_priority', 'table_dir', 'figure_dir', 'random_seed', 'tree_visualization', 'pause_at_each_step', 'terminal_num_points', 'session_name', 'start_time', 'end_time', 'time_used', 'terminal_num_points_over_n', 'smallest_terminal_points_over_n', 'comparison', 'full_figure_path']
#
# Full figure paths for HPC3 access:
# n= 3: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_180844_3by3
# n= 4: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_180844_4by4
# n= 5: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_180844_5by5
# n= 6: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_181045_6by6
# n= 7: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_173447_7by7
# n= 8: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_181004_8by8
# n= 9: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_181002_9by9
# n=10: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_181018_10by10
# n=11: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_181028_11by11
# n=12: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_180856_12by12
# n=13: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_183543_13by13
# n=14: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_180855_14by14
# n=15: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_185102_15by15
# n=16: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_183834_16by16
# n=17: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_180852_17by17
# n=18: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_192002_18by18
# n=19: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_185004_19by19
# n=20: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_182846_20by20
# n=21: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_203259_21by21
# n=22: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_182358_22by22
# n=23: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_200306_23by23
# n=25: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_205224_25by25
# n=26: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_222405_26by26
# n=27: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_192450_27by27
# n=28: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_184041_28by28
# n=29: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_180852_29by29
# n=30: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_194341_30by30
# n=31: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_234655_31by31
# n=32: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_222132_32by32
# n=33: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250813_085901_33by33
# n=34: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_194040_34by34
# n=35: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250813_033423_35by35
# n=36: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_234724_36by36
# n=37: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_180853_37by37
# n=38: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250813_060845_38by38
# n=39: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250813_045414_39by39
# n=40: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_212642_40by40
# n=41: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_180858_41by41
# n=42: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250813_024352_42by42
# n=43: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_230956_43by43
# n=44: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250813_043353_44by44
# n=45: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_180857_45by45
# n=46: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_180857_46by46
# n=47: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250813_021336_47by47
# n=48: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_180855_48by48
# n=50: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250813_004840_50by50
# n=51: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_192119_51by51
# n=52: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_180853_52by52
# n=53: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_181426_53by53
# n=54: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_192119_54by54
# n=55: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_192118_55by55
# n=56: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_182354_56by56
# n=57: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_182715_57by57
# n=58: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_183019_58by58
# n=59: /dfs6/pub/luoninz1/RLMath/tests/test_mcts_smallest_complete_v2/figure/20250812_183459_59by59
