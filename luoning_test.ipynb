# %%
from src.utils import parse_config, get_logger

# %%
config = parse_config()
logger = get_logger("test", config)

# %%
logger.warn("This is a test log message.")
# Out:
# This is a test log message.
# /var/folders/rf/j2243n211434v9h6hz0cc8fc0000gn/T/ipykernel_47407/519629862.py:1: DeprecationWarning: The 'warn' method is deprecated, use 'warning' instead
#   logger.warn("This is a test log message.")

# %%
from tqdm import trange
for i in trange(10, desc="Progress"):
    logger.info(f"Processing {i}")

for i in trange(10, desc="Progress"):
    logger.warning(f"Processing {i}")



for i in trange(10, desc="Progress"):
    logger.error(f"Processing {i}")

for i in trange(10, desc="Progress"):
    logger.critical(f"Processing {i}")
# Out:
# Progress:   0%|          | 0/10 [00:00<?, ?it/s]
# Processing 0
# Processing 1
# Processing 2
# Processing 3
# Processing 4
# Processing 5
# Processing 6
# Processing 7
# Processing 8
# Processing 9
# ...
# Progress:   0%|          | 0/10 [00:00<?, ?it/s]
# Processing 0
# Processing 1
# Processing 2
# Processing 3
# Processing 4
# Processing 5
# Processing 6
# Processing 7
# Processing 8
# Processing 9
# ...
# Progress:   0%|          | 0/10 [00:00<?, ?it/s]
# Processing 0
# Processing 1
# Processing 2
# Processing 3
# Processing 4
# Processing 5
# Processing 6
# Processing 7
# Processing 8
# Processing 9
# ...
# Progress:   0%|          | 0/10 [00:00<?, ?it/s]
# Processing 0
# Processing 1
# Processing 2
# Processing 3
# Processing 4
# Processing 5
# Processing 6
# Processing 7
# Processing 8
# Processing 9
# Progress: 100%|██████████| 10/10 [00:00<00:00, 2304.69it/s]

# %%
import numpy as np

array = np.array([[1, 2, 3],[4, 5, 6]])

logger.info(f"Array: {array}")
# Out:
# Array: [[1 2 3]
#  [4 5 6]]
